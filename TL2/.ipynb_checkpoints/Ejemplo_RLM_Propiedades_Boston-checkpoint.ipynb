# %%
#1-Importamos las librerias
import pandas as pd
import numpy as np
import sklearn 
import requests
from bs4 import BeautifulSoup
#LIbrerias de visualizacion:
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
#Para regresiòn lineal:
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
#2-Carga de DS
from sklearn import datasets
boston = datasets.load_boston()

# %%
type(boston)
# Out:
# sklearn.utils.Bunch

# %%
from sklearn.utils import Bunch

# %%
#Analisis del DS:
boston.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
print(boston['DESCR'])
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
#4-Creamos el DF con Pandas:
VectorDataBoston = boston['data'] #DF para la data e input
VectorHeadersBoston = boston['feature_names'] #DF para los headers

# %%
VectorDataBoston
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
VectorDataBoston.shape
# Out:
# (506, 13)

# %%
VectorHeadersBoston
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
DFBoston=pd.DataFrame(data=VectorDataBoston, columns=VectorHeadersBoston) #Definimos el DF.
DFBoston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
#5-Entendiento la variable target a predecir:
ValoresTarget=boston['target']
ValoresTarget.shape
# Out:
# (506,)

# %%
DFBoston['MEDV']=boston['target']

# %%
#Movemos la variable target al frente de la tabla:
Y = DFBoston.MEDV.copy()
del DFBoston['MEDV']
DFBoston = pd.concat((Y,DFBoston), axis=1)
DFBoston.head()
# Out:
#    MEDV     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  24.0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  21.6  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  34.7  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  33.4  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  36.2  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
#Limpiamos la data:
DFBoston.dtypes
# Out:
# MEDV       float64
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD        float64
# TAX        float64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# dtype: object

# %%
DFBoston.isnull().sum()
# Out:
# MEDV       0
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# dtype: int64

# %%
#Removemos algunas columnas:
for col in ['ZN','NOX', 'RAD', 'PTRATIO', 'B']:
    del DFBoston[col]

# %%
DFBoston.head()
# Out:
#    MEDV     CRIM  INDUS  CHAS     RM   AGE     DIS    TAX  LSTAT
# 0  24.0  0.00632   2.31   0.0  6.575  65.2  4.0900  296.0   4.98
# 1  21.6  0.02731   7.07   0.0  6.421  78.9  4.9671  242.0   9.14
# 2  34.7  0.02729   7.07   0.0  7.185  61.1  4.9671  242.0   4.03
# 3  33.4  0.03237   2.18   0.0  6.998  45.8  6.0622  222.0   2.94
# 4  36.2  0.06905   2.18   0.0  7.147  54.2  6.0622  222.0   5.33

# %%
#7-Exploraciòn y anàlisis de datos:
DFBoston.describe().T
# Out:
#        count        mean         std        min         25%        50%  \
# MEDV   506.0   22.532806    9.197104    5.00000   17.025000   21.20000
# CRIM   506.0    3.613524    8.601545    0.00632    0.082045    0.25651
# INDUS  506.0   11.136779    6.860353    0.46000    5.190000    9.69000
# CHAS   506.0    0.069170    0.253994    0.00000    0.000000    0.00000
# RM     506.0    6.284634    0.702617    3.56100    5.885500    6.20850
# AGE    506.0   68.574901   28.148861    2.90000   45.025000   77.50000
# DIS    506.0    3.795043    2.105710    1.12960    2.100175    3.20745
# TAX    506.0  408.237154  168.537116  187.00000  279.000000  330.00000
# LSTAT  506.0   12.653063    7.141062    1.73000    6.950000   11.36000
#
#               75%       max
# MEDV    25.000000   50.0000
# CRIM     3.677083   88.9762
# INDUS   18.100000   27.7400
# CHAS     0.000000    1.0000
# RM       6.623500    8.7800
# AGE     94.075000  100.0000
# DIS      5.188425   12.1265
# ...

# %%
#Seguimos diminuyendo el nùmero de variables:
#VER ESTO QUÈ SE USO. 
cols=['RM','AGE','TAX','LSTAT','MEDV']
NewDFBoston=DFBoston[cols]
NewDFBoston.head()
# Out:
#       RM   AGE    TAX  LSTAT  MEDV
# 0  6.575  65.2  296.0   4.98  24.0
# 1  6.421  78.9  242.0   9.14  21.6
# 2  7.185  61.1  242.0   4.03  34.7
# 3  6.998  45.8  222.0   2.94  33.4
# 4  7.147  54.2  222.0   5.33  36.2

# %%
#Analizamos factor de correlaciòn entre las variables:
NewDFBoston.corr()
# Out:
#              RM       AGE       TAX     LSTAT      MEDV
# RM     1.000000 -0.240265 -0.292048 -0.613808  0.695360
# AGE   -0.240265  1.000000  0.506456  0.602339 -0.376955
# TAX   -0.292048  0.506456  1.000000  0.543993 -0.468536
# LSTAT -0.613808  0.602339  0.543993  1.000000 -0.737663
# MEDV   0.695360 -0.376955 -0.468536 -0.737663  1.000000

# %%
ax = sns.heatmap(NewDFBoston.corr(), 
                 cmap=sns.cubehelix_palette(20, light=0.95,dark=0.15))
#ax.axis.tick_top() #Mueve los labels hacia arriba, al parecer ya no existe más esta funcion.

plt.savefig('Figures/HeatMapHoustonHousing.png',
           bbox_inches='tight', dpi=300)

# %%
sns.pairplot(NewDFBoston, 
             plot_kws={'alpha':0.6}, 
             diag_kws={'bins':30})

# %%
#Realizamos un analisis predictivo mediante un modelo de REgresiòn Lineal.
#Para esto usaremos las variables / features RM y LSTAT. 

#ACA VER EL ANALISIS PARA LLEGAR A QUE USAMOS ESAS 2 VARIABLES
#SIN ESO DE LOS RESIDUOS, ESO DESPUES VER COMO MEJORA.

#ESTO DE REGRESION LINEAL HACERLO COMO YO HACIA JEJE
