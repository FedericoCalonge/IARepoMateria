# %% [markdown]
# # <h1 style="color:blue"> TL1 - Punto 2) Analisis de Datos COVID-19</h1>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy as sc
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
# %run ./TL1-Pto2-FuncionesExtra.ipynb

# %%
paises=miTop(3)
#paises=["Argentina", "China", "Spain"]
#print(paises)

# %%
miFuncion("Argentina")

# %%
for x in paises:
    print(x)
    miFuncion(x)
# Out:
# US
# Spain
# Italy
