# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy as sc
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
# %run ./TL1-B1Ima.ipynb

# %%
paises=miTop(3)
#paises=["Argentina", "China", "Spain"]
#print(paises)

# %%
miFuncion("Argentina")

# %%
for x in paises:
    print(x)
    miFuncion(x)
# Out:
# US
# Spain
# Italy
